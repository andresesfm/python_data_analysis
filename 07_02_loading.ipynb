# %%
import numpy as np
import matplotlib.pyplot as pp
import pandas as pd
import seaborn

# %%
# %matplotlib inline

# %%
import zipfile

# %%
zipfile.ZipFile('names.zip').extractall('.')

# %%
import os
os.listdir('names')
# Out:
# ['yob1994.txt',
#  'yob1912.txt',
#  'yob1956.txt',
#  'yob1935.txt',
#  'yob1898.txt',
#  'yob1902.txt',
#  'yob1937.txt',
#  'yob2012.txt',
#  'yob1910.txt',
#  'yob1927.txt',
#  'yob1899.txt',
#  'yob1921.txt',
#  'yob1942.txt',
#  'yob1895.txt',
#  'yob1888.txt',
#  'yob1982.txt',
#  'yob1885.txt',
#  'yob1970.txt',
#  'yob1946.txt',
#  'yob1925.txt',
#  'yob1992.txt',
#  'yob1958.txt',
#  'yob1977.txt',
#  'yob1955.txt',
#  'yob1936.txt',
#  'yob2011.txt',
#  'yob1923.txt',
#  'yob1930.txt',
#  'yob1916.txt',
#  'yob1967.txt',
#  'yob1920.txt',
#  'yob1948.txt',
#  'yob1915.txt',
#  'yob2016.txt',
#  'yob1990.txt',
#  'yob1962.txt',
#  'yob1890.txt',
#  'yob1951.txt',
#  'yob2007.txt',
#  'yob1906.txt',
#  'yob1903.txt',
#  'yob1904.txt',
#  'yob1881.txt',
#  'yob1918.txt',
#  'yob2000.txt',
#  'yob1907.txt',
#  'yob1901.txt',
#  'yob1905.txt',
#  'yob1989.txt',
#  'yob1997.txt',
#  'yob1973.txt',
#  'yob1938.txt',
#  'yob1892.txt',
#  'yob1986.txt',
#  'yob1929.txt',
#  'yob2001.txt',
#  'yob1950.txt',
#  'yob1969.txt',
#  'yob1931.txt',
#  'yob1919.txt',
#  'yob1932.txt',
#  'yob1987.txt',
#  'yob1926.txt',
#  'yob1971.txt',
#  'yob2010.txt',
#  'yob1981.txt',
#  'yob2005.txt',
#  'yob1941.txt',
#  'yob1924.txt',
#  'yob1911.txt',
#  'yob2008.txt',
#  'yob1965.txt',
#  'yob1908.txt',
#  'yob1897.txt',
#  'yob2013.txt',
#  'yob1993.txt',
#  'yob1886.txt',
#  'yob1945.txt',
#  'yob1900.txt',
#  'yob1985.txt',
#  'yob1972.txt',
#  'yob1952.txt',
#  'yob1928.txt',
#  'yob1998.txt',
#  'yob2006.txt',
#  'yob2014.txt',
#  'yob1978.txt',
#  'yob1988.txt',
#  'yob1887.txt',
#  'yob2015.txt',
#  'yob1883.txt',
#  'yob1909.txt',
#  'yob1949.txt',
#  'yob2017.txt',
#  'yob1953.txt',
#  'yob1976.txt',
#  'yob1934.txt',
#  'yob1979.txt',
#  'yob1896.txt',
#  'yob1922.txt',
#  'yob1975.txt',
#  'yob1889.txt',
#  'yob1940.txt',
#  'yob1991.txt',
#  'yob1954.txt',
#  'yob1943.txt',
#  'yob1957.txt',
#  'yob1961.txt',
#  'yob1914.txt',
#  'yob1944.txt',
#  'yob1939.txt',
#  'yob1984.txt',
#  'yob1893.txt',
#  'yob1968.txt',
#  'yob1960.txt',
#  'yob1963.txt',
#  'yob1983.txt',
#  'yob1980.txt',
#  'yob1999.txt',
#  'yob1933.txt',
#  'yob2003.txt',
#  'yob1894.txt',
#  'yob1995.txt',
#  'yob1966.txt',
#  'yob1964.txt',
#  'yob2002.txt',
#  'yob1880.txt',
#  'yob1947.txt',
#  'yob1959.txt',
#  'yob1917.txt',
#  'yob1884.txt',
#  'yob1974.txt',
#  'yob2004.txt',
#  'yob1891.txt',
#  'yob2009.txt',
#  'yob1882.txt',
#  'yob1996.txt',
#  'yob1913.txt']

# %%
open('names/yob2011.txt','r').readlines()[:10]
# Out:
# ['Sophia,F,21837\n',
#  'Isabella,F,19901\n',
#  'Emma,F,18797\n',
#  'Olivia,F,17321\n',
#  'Ava,F,15496\n',
#  'Emily,F,14251\n',
#  'Abigail,F,13247\n',
#  'Madison,F,12381\n',
#  'Mia,F,11527\n',
#  'Chloe,F,10988\n']

# %%
names2011 = pd.read_csv('names/yob2011.txt')

# %%
names2011.head()
# Out:
#      Sophia  F  21837
# 0  Isabella  F  19901
# 1      Emma  F  18797
# 2    Olivia  F  17321
# 3       Ava  F  15496
# 4     Emily  F  14251

# %%
names2011 = pd.read_csv('names/yob2011.txt',names=['name','sex','number'])

# %%
names2011.head()
# Out:
#        name sex  number
# 0    Sophia   F   21837
# 1  Isabella   F   19901
# 2      Emma   F   18797
# 3    Olivia   F   17321
# 4       Ava   F   15496

# %%
names_all=[]

for year in range(1880,2014+1):
    names_all.append(pd.read_csv(f'names/yob{year}.txt',names=['name','sex','number']))
    names_all[-1]['year'] = year

allyears = pd.concat(names_all)

# %%
allyears.head()
# Out:
#         name sex  number  year
# 0       Mary   F    7065  1880
# 1       Anna   F    2604  1880
# 2       Emma   F    2003  1880
# 3  Elizabeth   F    1939  1880
# 4     Minnie   F    1746  1880

# %%
allyears.tail()
# Out:
#           name sex  number  year
# 33223   Zykeem   M       5  2014
# 33224   Zymeer   M       5  2014
# 33225  Zymiere   M       5  2014
# 33226    Zyran   M       5  2014
# 33227    Zyrin   M       5  2014

# %%
#allyears.set_index('name')

# %%
#allyears.iloc['Elizabeth']

# %% [markdown]
# # Popularity

# %%
allyears_indexed = allyears.set_index(['sex','name','year']).sort_index()

# %%
allyears_indexed
# Out:
#                     number
# sex name      year
# F   Aabha     2011       7
#               2012       5
#               2014       9
#     Aabriella 2008       5
#               2014       5
#     Aaden     2009       5
#     Aadhira   2012       6
#               2013      10
#               2014      13
#     Aadhya    2007      10
#               2008       9
#               2009      18
#               2010      19
#               2011      52
#               2012     110
#               2013     172
#               2014     249
#     Aadi      2006       5
#               2012       5
#               2013       6
#     Aadison   2009       6
#               2012       5
#     Aaditri   2010       5
#               2012       5
#               2013       6
#               2014      10
#     Aadrika   2013       5
#               2014       5
#     Aadvika   2013       6
#               2014       7
# ...                    ...
# M   Zyshawn   2008      14
#               2009       7
#               2010       9
#               2011       5
#               2012      10
#               2013      13
#               2014       6
#     Zyshon    1998       8
#               2001       6
#               2005       5
#     Zyshonne  1998      26
#               1999      30
#               2000      17
#               2001      12
#               2002       9
#               2003       7
#     Zytaevius 2012       5
#     Zytaveon  2011       8
#               2014       8
#     Zytavion  2011       5
#     Zytavious 2002       6
#               2004       6
#               2005       5
#               2006       7
#               2007       6
#               2009       7
#               2010       6
#     Zyvion    2009       5
#     Zyyon     2014       6
#     Zzyzx     2010       5
#
# [1826119 rows x 1 columns]

# %%
allyears_indexed.loc['F','Mary']
# Out:
#       number
# year
# 1880    7065
# 1881    6919
# 1882    8148
# 1883    8012
# 1884    9217
# 1885    9128
# 1886    9889
# 1887    9888
# 1888   11754
# 1889   11648
# 1890   12078
# 1891   11703
# 1892   13172
# 1893   12784
# 1894   13151
# 1895   13446
# 1896   13811
# 1897   13413
# 1898   14406
# 1899   13172
# 1900   16706
# 1901   13136
# 1902   14486
# 1903   14275
# 1904   14961
# 1905   16067
# 1906   16370
# 1907   17580
# 1908   18665
# 1909   19259
# ...      ...
# 1985    9244
# 1986    8506
# 1987    8395
# 1988    8510
# 1989    8644
# 1990    8666
# 1991    8760
# 1992    8458
# 1993    8119
# 1994    7751
# 1995    7452
# 1996    6956
# 1997    6636
# 1998    6443
# 1999    6372
# 2000    6192
# 2001    5729
# 2002    5460
# 2003    5016
# 2004    4809
# 2005    4454
# 2006    4090
# 2007    3679
# 2008    3497
# 2009    3160
# 2010    2866
# 2011    2706
# 2012    2574
# 2013    2646
# 2014    2630
#
# [135 rows x 1 columns]

# %%
def plotname(sex,name):
    data = allyears_indexed.loc[sex,name]
    
    pp.plot(data.index,data.values)

# %%
pp.figure(figsize=(12,3))
names = ['Michael','John','David','Martin']

for name in names:
    plotname('M',name)
pp.legend(names)

# %%
pp.figure(figsize=(12,3))
names = ['Emily','Anna','Claire','Elizabeth']

for name in names:
    plotname('F',name)
pp.legend(names)

# %%
pp.figure(figsize=(12,3))
names = ['Andres','Andrew','William']

for name in names:
    plotname('M',name)
pp.legend(names)

# %%
pp.figure(figsize=(12,3))
names = ['Chiara','Claire','Clare','Clara','Ciara']

for name in names:
    plotname('F',name)
pp.legend(names)

# %%
allyears_indexed.loc['F'].loc[names].head()
# Out:
#              number
# name   year
# Chiara 1959       9
#        1960       5
#        1962       8
#        1963       8
#        1964      12

# %%
allyears_indexed.loc['F'].loc[names].unstack(level=0).head()
# Out:
#      number
# name Chiara Ciara Claire   Clara Clare
# year
# 1880    NaN   NaN   21.0  1226.0  15.0
# 1881    NaN   NaN   23.0  1242.0  20.0
# 1882    NaN   NaN   30.0  1490.0  21.0
# 1883    NaN   NaN   38.0  1548.0  22.0
# 1884    NaN   NaN   33.0  1852.0  38.0

# %%
allyears_indexed.loc['F'].loc[names].unstack(level=0).fillna(0).head()
# Out:
#      number
# name Chiara Ciara Claire   Clara Clare
# year
# 1880    0.0   0.0   21.0  1226.0  15.0
# 1881    0.0   0.0   23.0  1242.0  20.0
# 1882    0.0   0.0   30.0  1490.0  21.0
# 1883    0.0   0.0   38.0  1548.0  22.0
# 1884    0.0   0.0   33.0  1852.0  38.0

# %%
variants = allyears_indexed.loc['F'].loc[names].unstack(level=0).fillna(0)

# %%
variants.head()
# Out:
#      number
# name Chiara Ciara Claire   Clara Clare
# year
# 1880    0.0   0.0   21.0  1226.0  15.0
# 1881    0.0   0.0   23.0  1242.0  20.0
# 1882    0.0   0.0   30.0  1490.0  21.0
# 1883    0.0   0.0   38.0  1548.0  22.0
# 1884    0.0   0.0   33.0  1852.0  38.0

# %%
pp.figure(figsize=(12,3))
#Note: I used labels instead of label as per documentation
pp.stackplot(variants.index,variants.values.T,labels=names)
# Out:
# [<matplotlib.collections.PolyCollection at 0x7fb7e23b5588>,
#  <matplotlib.collections.PolyCollection at 0x7fb7e23b57f0>,
#  <matplotlib.collections.PolyCollection at 0x7fb7e23b5a58>,
#  <matplotlib.collections.PolyCollection at 0x7fb7e23b5cc0>,
#  <matplotlib.collections.PolyCollection at 0x7fb7e23b5f28>]

# %%
pp.figure(figsize=(12,3))
palette = seaborn.color_palette()
pp.stackplot(variants.index,variants.values.T,colors=palette)

for i, name in enumerate(names):
    pp.text(1882,5000+800*i, name,color=palette[i])

# %% [markdown]
# # Top Ten

# %%
allyears_indexed.loc['M',:,2008].sort_values('number', ascending=False).head()
# Out:
#                   number
# sex name    year
# M   Jacob   2008   22591
#     Michael 2008   20617
#     Ethan   2008   20211
#     Joshua  2008   19200
#     Daniel  2008   19001

# %%
pop2008 = allyears_indexed.loc['M',:,2008].sort_values('number', ascending=False).head()

# %%
pop2008.reset_index().drop(['sex','year','number'],axis=1).head()
# Out:
#       name
# 0    Jacob
# 1  Michael
# 2    Ethan
# 3   Joshua
# 4   Daniel

# %%
def topten(sex,year):
    simple = allyears_indexed.loc[sex,:,year].sort_values('number', ascending=False).reset_index()
    simple = simple.drop(['sex','year','number'],axis=1).head(10)
    #Using rename instead od assigning columns
    simple.rename(columns={'name':year}, inplace=True)
    simple.index = simple.index+1
    return simple

# %%
topten('M',2009)
# Out:
#            2009
# 1         Jacob
# 2         Ethan
# 3       Michael
# 4     Alexander
# 5       William
# 6        Joshua
# 7        Daniel
# 8        Jayden
# 9          Noah
# 10  Christopher

# %%
def toptens(sex,year0,year1):
    years = [topten(sex,year) for year in range(year0,year1+1)]
    return years[0].join(years[1:])

# %%
toptens('M',2000,2010)
# Out:
#            2000         2001         2002         2003         2004  \
# 1         Jacob        Jacob        Jacob        Jacob        Jacob
# 2       Michael      Michael      Michael      Michael      Michael
# 3       Matthew      Matthew       Joshua       Joshua       Joshua
# 4        Joshua       Joshua      Matthew      Matthew      Matthew
# 5   Christopher  Christopher        Ethan       Andrew        Ethan
# 6      Nicholas     Nicholas       Andrew       Joseph       Andrew
# 7        Andrew       Andrew       Joseph        Ethan       Daniel
# 8        Joseph       Joseph  Christopher       Daniel      William
# 9        Daniel       Daniel     Nicholas  Christopher       Joseph
# 10        Tyler      William       Daniel      Anthony  Christopher
#
#            2005         2006         2007         2008         2009       2010
# 1         Jacob        Jacob        Jacob        Jacob        Jacob      Jacob
# 2       Michael      Michael      Michael      Michael        Ethan      Ethan
# 3        Joshua       Joshua        Ethan        Ethan      Michael    Michael
# 4       Matthew        Ethan       Joshua       Joshua    Alexander     Jayden
# 5         Ethan      Matthew       Daniel       Daniel      William    William
# 6        Andrew       Daniel  Christopher    Alexander       Joshua  Alexander
# 7        Daniel       Andrew      Anthony      Anthony       Daniel       Noah
# 8       Anthony  Christopher      William      William       Jayden     Daniel
# 9        Joseph      Anthony      Matthew  Christopher         Noah      Aiden
# 10  Christopher      William       Andrew      Matthew  Christopher    Anthony

# %%
toptens('F',1985,1995)
# Out:
#          1985       1986       1987       1988       1989       1990  \
# 1     Jessica    Jessica    Jessica    Jessica    Jessica    Jessica
# 2      Ashley     Ashley     Ashley     Ashley     Ashley     Ashley
# 3    Jennifer     Amanda     Amanda     Amanda   Brittany   Brittany
# 4      Amanda   Jennifer   Jennifer      Sarah     Amanda     Amanda
# 5       Sarah      Sarah      Sarah   Jennifer      Sarah   Samantha
# 6   Stephanie  Stephanie  Stephanie   Brittany   Samantha      Sarah
# 7      Nicole     Nicole   Brittany  Stephanie   Jennifer  Stephanie
# 8     Heather   Brittany     Nicole   Samantha  Stephanie   Jennifer
# 9   Elizabeth    Heather    Heather     Nicole     Lauren  Elizabeth
# 10      Megan  Elizabeth  Elizabeth  Elizabeth  Elizabeth     Lauren
#
#          1991       1992       1993       1994       1995
# 1      Ashley     Ashley    Jessica    Jessica    Jessica
# 2     Jessica    Jessica     Ashley     Ashley     Ashley
# 3    Brittany     Amanda      Sarah      Emily      Emily
# 4      Amanda   Brittany   Samantha   Samantha   Samantha
# 5    Samantha      Sarah      Emily      Sarah      Sarah
# 6       Sarah   Samantha   Brittany     Taylor     Taylor
# 7   Stephanie      Emily     Taylor   Brittany     Hannah
# 8    Jennifer  Stephanie     Amanda     Amanda   Brittany
# 9   Elizabeth  Elizabeth  Elizabeth  Elizabeth     Amanda
# 10      Emily      Megan  Stephanie      Megan  Elizabeth

# %%
toptens('F',1985,1995).stack().head()
# Out:
# 1  1985    Jessica
#    1986    Jessica
#    1987    Jessica
#    1988    Jessica
#    1989    Jessica
# dtype: object

# %%
toptens('F',1985,1995).stack().value_counts()
# Out:
# Jessica      11
# Ashley       11
# Amanda       11
# Elizabeth    11
# Sarah        11
# Brittany     10
# Stephanie     9
# Samantha      8
# Jennifer      7
# Emily         5
# Nicole        4
# Megan         3
# Taylor        3
# Heather       3
# Lauren        2
# Hannah        1
# dtype: int64

# %%
popular = toptens('F',1985,1995).stack().value_counts().index[:6]

# %%
pp.figure(figsize=(12,3))

for name in popular:
    plotname('F',name)

pp.legend(popular)
